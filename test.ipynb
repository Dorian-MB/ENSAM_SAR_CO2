# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path

from eco2_normandy import Simulation
from optimizer.orchestrator import OptimizationOrchestrator
from optimizer.CPModel import CpModel
from optimizer.GAModel import GaModel 
from eco2_normandy.tools import get_simlulation_variable

# %%
path = "scenarios/dev/phase3_bergen_18k_2boats.yaml"
config = get_simlulation_variable(path)[0]
config["general"]["num_period"] = 1000
sim = Simulation(config=config, config_name="test", verbose=True)
sim.run()
print(sim.factory._total_maintenance_time)
# Out:
# INFO :	Starting simulation n°1...
# INFO :	Simulation done, collecting data...
# INFO :	⏱️ Simulation time: 0.023662 seconds
# 531.0

# %%
kpis = sim.get_kpis_generator(False)

# %%
graphs = kpis.generate_kpis_graphs()
for g in graphs:
    g.show()
